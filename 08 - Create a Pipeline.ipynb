# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.20.0 to work with training_dp100

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "ClusterDP100"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [e48e1496][1c56b85f-1b18-4337-a722-c68065c473b6], (This step will run and generate new outputs)
# Created step Train and Register Model [8b0838d8][e9c7a50e-ecb4-48f3-9072-079664e34316], (This step will run and generate new outputs)
# Submitted PipelineRun 8443e42e-9995-4eb6-a12a-ced603fb2407
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/8443e42e-9995-4eb6-a12a-ced603fb2407?wsid=/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourcegroups/azuredp-100/workspaces/training_dp100
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 8443e42e-9995-4eb6-a12a-ced603fb2407
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/8443e42e-9995-4eb6-a12a-ced603fb2407?wsid=/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourcegroups/azuredp-100/workspaces/training_dp100
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 7fae51d9-0f1c-4725-bcb6-4faf9f659449
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/7fae51d9-0f1c-4725-bcb6-4faf9f659449?wsid=/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourcegroups/azuredp-100/workspaces/training_dp100
# StepRun( Prepare Data ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/02/02 14:30:10 Downloading source code...
# 2021/02/02 14:30:13 Finished downloading source code
# 2021/02/02 14:30:14 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/02/02 14:30:14 Successfully set up Docker network: acb_default_network
# 2021/02/02 14:30:14 Setting up Docker configuration...
# 2021/02/02 14:30:15 Successfully set up Docker configuration
# 2021/02/02 14:30:15 Logging in to registry: fd5d9572f8b74f5e933fceba46da77ff.azurecr.io
# 2021/02/02 14:30:17 Successfully logged into fd5d9572f8b74f5e933fceba46da77ff.azurecr.io
# 2021/02/02 14:30:17 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/02 14:30:17 Scanning for dependencies...
# 2021/02/02 14:30:18 Successfully scanned dependencies
# 2021/02/02 14:30:18 Launching container with name: acb_step_0
# Sending build context to Docker daemon  65.02kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/15 : USER root
#  ---> Running in 8fab17a1f48f
# Removing intermediate container 8fab17a1f48f
#  ---> 3bae74a890ba
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in f39588c67b20
# Removing intermediate container f39588c67b20
#  ---> 20bb90ffeda8
# Step 4/15 : WORKDIR /
#  ---> Running in 9aa7021e96b3
# Removing intermediate container 9aa7021e96b3
#  ---> 58e1084920b0
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
# StepRun( Prepare Data ) Status: Running
#  ---> 5d423ac81208
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in a7cb989ec173
# Removing intermediate container a7cb989ec173
#  ---> 747ce74bab5b
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 1f3369a441db
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 348098382c59
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | 2          |   2%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | #######    |  70%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ##8        |  28%
# pandas-1.1.3         | 10.5 MB   | ######9    |  69%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ###1       |  31%
# numpy-base-1.19.1    | 5.2 MB    | #########6 |  96%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | 6          |   7%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #1         |  12%
# icu-58.2             | 22.7 MB   | ###2       |  32%
# icu-58.2             | 22.7 MB   | #####8     |  59%
# icu-58.2             | 22.7 MB   | #######2   |  73%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ######3    |  64%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | 5          |   6%
# tk-8.6.10            | 3.2 MB    | ##4        |  24%
# tk-8.6.10            | 3.2 MB    | #######    |  71%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | #########1 |  92%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | 2          |   2%
# python-3.6.2         | 27.0 MB   | #9         |  20%
# python-3.6.2         | 27.0 MB   | ####3      |  44%
# python-3.6.2         | 27.0 MB   | #######1   |  71%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #########3 |  93%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | #3         |  13%
# scipy-1.5.2          | 18.5 MB   | ####5      |  46%
# scipy-1.5.2          | 18.5 MB   | ########7  |  87%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | #########5 |  95%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ##9        |  30%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 2          |   2%
# qt-5.9.6             | 86.7 MB   | #          |  11%
# qt-5.9.6             | 86.7 MB   | #5         |  15%
# qt-5.9.6             | 86.7 MB   | #9         |  20%
# qt-5.9.6             | 86.7 MB   | ##5        |  26%
# qt-5.9.6             | 86.7 MB   | ###4       |  34%
# qt-5.9.6             | 86.7 MB   | ####2      |  42%
# qt-5.9.6             | 86.7 MB   | ####9      |  49%
# qt-5.9.6             | 86.7 MB   | #####5     |  56%
# qt-5.9.6             | 86.7 MB   | ######3    |  64%
# qt-5.9.6             | 86.7 MB   | #######2   |  72%
# qt-5.9.6             | 86.7 MB   | #######9   |  80%
# qt-5.9.6             | 86.7 MB   | ########7  |  87%
# qt-5.9.6             | 86.7 MB   | #########4 |  95%
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ##4        |  25%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #4         |  15%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ######9    |  69%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | #######9   |  79%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 4          |   5%
# mkl-2019.4           | 204.1 MB  | 8          |   8%
# mkl-2019.4           | 204.1 MB  | #2         |  12%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##2        |  22%
# mkl-2019.4           | 204.1 MB  | ##5        |  26%
# mkl-2019.4           | 204.1 MB  | ##9        |  29%
# mkl-2019.4           | 204.1 MB  | ###2       |  33%
# mkl-2019.4           | 204.1 MB  | ###5       |  36%
# mkl-2019.4           | 204.1 MB  | ###8       |  39%
# mkl-2019.4           | 204.1 MB  | ####2      |  43%
# mkl-2019.4           | 204.1 MB  | ####5      |  46%
# mkl-2019.4           | 204.1 MB  | ####9      |  50%
# mkl-2019.4           | 204.1 MB  | #####2     |  53%
# mkl-2019.4           | 204.1 MB  | #####6     |  56%
# mkl-2019.4           | 204.1 MB  | #####9     |  60%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  75%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ######7    |  68%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.889i1ezi.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.20.0
#   Downloading azureml_defaults-1.20.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.9.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.20.0
#   Downloading azureml_dataset_runtime-1.20.0-py3-none-any.whl (3.4 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-core~=1.20.0
#   Downloading azureml_core-1.20.0.post1-py3-none-any.whl (2.1 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-dataprep-native<30.0.0,>=29.0.0
#   Downloading azureml_dataprep_native-29.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.8.0a,>=1.7.0dev0
#   Downloading azureml_dataprep_rslex-1.7.0-cp36-cp36m-manylinux2010_x86_64.whl (8.5 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 2)) (1.19.1)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 1)) (2.8.1)
# Collecting jsonpickle
#   Downloading jsonpickle-1.5.1-py2.py3-none-any.whl (37 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting docker
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 1)) (2020.1)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 1)) (1.15.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.8.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.10.0-py2.py3-none-any.whl (125 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.20.0->azureml-defaults~=1.20.0->-r /azureml-environment-setup/condaenv.889i1ezi.requirements.txt (line 1)) (2020.6.20)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=05f9f15d6e5a02913286767dc791e68bc39a8529eb54ee215921267f013af698
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=50920b5e1b15595007e1cc366a2d7f692041f691f178b654ed2aab4ddd90d5c3
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=5a7c6e67581ceecbccc01a494a33b26e3b4e88ba8124a376c9cc21a40a5e130d
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: werkzeug, configparser, applicationinsights, azureml-dataprep-native, cloudpickle, distro, dotnetcore2, portalocker, PyJWT, urllib3, chardet, idna, requests, pycparser, cffi, cryptography, msal, msal-extensions, azure-core, azure-identity, azureml-dataprep-rslex, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, itsdangerous, click, MarkupSafe, Jinja2, flask, pyopenssl, pyasn1, ndg-httpsclient, ruamel.yaml.clib, ruamel.yaml, backports.weakref, backports.tempfile, azure-common, jmespath, isodate, oauthlib, requests-oauthlib, msrest, typing-extensions, zipp, importlib-metadata, jsonpickle, adal, msrestazure, azure-mgmt-containerregistry, azure-mgmt-keyvault, azure-mgmt-resource, jeepney, SecretStorage, azure-graphrbac, azure-mgmt-authorization, contextlib2, websocket-client, docker, pathspec, azure-mgmt-storage, azureml-core, json-logging-py, gunicorn, dill, liac-arff, azureml-model-management-sdk, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.10.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.20.0.post1 azureml-dataprep-2.9.0 azureml-dataprep-native-29.0.0 azureml-dataprep-rslex-1.7.0 azureml-dataset-runtime-1.20.0 azureml-defaults-1.20.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.3.1 dill-0.3.3 distro-1.5.0 docker-4.4.1 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.4.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.5.1 liac-arff-2.5.0 msal-1.8.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 348098382c59
#  ---> 14655700227f
# Step 9/15 : ENV PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin:$PATH
#  ---> Running in 2f56f0cea972
# Removing intermediate container 2f56f0cea972
#  ---> 04d4bcbcb933
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2
#  ---> Running in 874dab2959c5
# Removing intermediate container 874dab2959c5
#  ---> ef2b8c45e0df
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/lib:$LD_LIBRARY_PATH
#  ---> Running in 9d66dcc4f61e
# Removing intermediate container 9d66dcc4f61e
#  ---> b3be2a3661c9
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 748714a4d565
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 3b9cd3f0d9d7
# Removing intermediate container 3b9cd3f0d9d7
#  ---> 043294ba0984
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 2b0019e6243d
# Removing intermediate container 2b0019e6243d
#  ---> 8bb5d7e60f25
# Step 15/15 : CMD ["bash"]
#  ---> Running in 770c22ead802
# Removing intermediate container 770c22ead802
#  ---> 2e7aac38b5c0
# Successfully built 2e7aac38b5c0
# Successfully tagged fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021/02/02 14:36:56 Successfully executed container: acb_step_0
# 2021/02/02 14:36:56 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/02 14:36:56 Pushing image: fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest, attempt 1
# The push refers to repository [fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90]
# f9f0d9523117: Preparing
# d56bba07ba53: Preparing
# 857e28ffcf44: Preparing
# 54733ebc2b68: Preparing
# e6ce23061189: Preparing
# 57e22148b696: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 57e22148b696: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# da2785b7bb16: Waiting
# bbc674332e2e: Waiting
# 857e28ffcf44: Pushed
# e6ce23061189: Pushed
# 54733ebc2b68: Pushed
# f9f0d9523117: Pushed
# 57e22148b696: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# 088c5f014be3: Pushed
# e342e7653d41: Pushed
# 5b7dc8292d9b: Pushed
# 1a1a19626b20: Pushed
# bbc674332e2e: Pushed
# 0c7d6f1219f0: Pushed
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
# d56bba07ba53: Pushed
# latest: digest: sha256:2dec016528f61357caa7418e7b918a596af618fadb981c14411aa4bba56749ed size: 4095
# 2021/02/02 14:40:02 Successfully pushed image: fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021/02/02 14:40:02 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 399.349374)
# 2021/02/02 14:40:02 Populating digests for step ID: acb_step_0...
# 2021/02/02 14:40:04 Successfully populated digests for step ID: acb_step_0
# 2021/02/02 14:40:04 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 186.358363)
# 2021/02/02 14:40:04 The following dependencies were found:
# 2021/02/02 14:40:04
# - image:
#     registry: fd5d9572f8b74f5e933fceba46da77ff.azurecr.io
#     repository: azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
#     tag: latest
#     digest: sha256:2dec016528f61357caa7418e7b918a596af618fadb981c14411aa4bba56749ed
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
#
# Run ID: cb3 was successful after 9m56s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# ========================================================================================================================
# 2021-02-02T14:43:30Z Starting output-watcher...
# 2021-02-02T14:43:30Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-02-02T14:43:32Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-02-02T14:43:32Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# bcd3a68824c3: Pulling fs layer
# 9f6c5e621659: Pulling fs layer
# baf0080bc3dd: Pulling fs layer
# 8a592801b6d7: Pulling fs layer
# 41d123e64ea4: Pulling fs layer
# 4e93e077b46f: Pulling fs layer
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# bcd3a68824c3: Waiting
# 9f6c5e621659: Waiting
# baf0080bc3dd: Waiting
# 8a592801b6d7: Waiting
# 41d123e64ea4: Waiting
# 4e93e077b46f: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# d887158cc58c: Pull complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# 9f6c5e621659: Verifying Checksum
# 9f6c5e621659: Download complete
# d54d011de0e3: Download complete
# baf0080bc3dd: Download complete
# bcd3a68824c3: Verifying Checksum
# bcd3a68824c3: Download complete
# 4e93e077b46f: Verifying Checksum
# 4e93e077b46f: Download complete
# 8a592801b6d7: Verifying Checksum
# 8a592801b6d7: Download complete
# baf7ab26f516: Pull complete
# 41d123e64ea4: Verifying Checksum
# 41d123e64ea4: Download complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# bcd3a68824c3: Pull complete
# 9f6c5e621659: Pull complete
# baf0080bc3dd: Pull complete
# 8a592801b6d7: Pull complete
# 41d123e64ea4: Pull complete
# 4e93e077b46f: Pull complete
# Digest: sha256:2dec016528f61357caa7418e7b918a596af618fadb981c14411aa4bba56749ed
# Status: Downloaded newer image for fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021-02-02T14:45:55Z Check if container 7fae51d9-0f1c-4725-bcb6-4faf9f659449 already exist exited with 0,
#
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/02/02 14:46:58 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/02/02 14:46:58 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-02-02T14:46:59.909966] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['prep_diabetes.py', '--input-data', '7ebe96a9-0cae-46f8-a4b3-217872040fc0', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/mounts/workspaceblobstore/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/prepped_data_folder'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 108
# Entering Run History Context Manager.
# [2021-02-02T14:47:03.236751] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/mounts/workspaceblobstore/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449
# [2021-02-02T14:47:03.244040] Preparing to call script [prep_diabetes.py] with arguments:['--input-data', '7ebe96a9-0cae-46f8-a4b3-217872040fc0', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/mounts/workspaceblobstore/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/prepped_data_folder']
# [2021-02-02T14:47:03.244259] After variable expansion, calling script [prep_diabetes.py] with arguments:['--input-data', '7ebe96a9-0cae-46f8-a4b3-217872040fc0', '--prepped-data', '/mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/mounts/workspaceblobstore/azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/prepped_data_folder']
#
# Loading Data...
# Saving Data...
#
# Streaming azureml-logs/75_job_post-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# ===============================================================================================================
# [2021-02-02T14:47:25.383999] Entering job release
# [2021-02-02T14:47:26.519859] Starting job release
# [2021-02-02T14:47:26.520708] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 345
# [2021-02-02T14:47:26.521137] job release stage : upload_datastore starting...
# [2021-02-02T14:47:26.523541] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-02-02T14:47:26.523573] job release stage : execute_job_release starting...
# [2021-02-02T14:47:26.530199] job release stage : copy_batchai_cached_logs starting...
# [2021-02-02T14:47:26.530713] job release stage : copy_batchai_cached_logs completed...
# [2021-02-02T14:47:26.531719] Entering context manager injector.
# [2021-02-02T14:47:26.707400] job release stage : upload_datastore completed...
# [2021-02-02T14:47:26.773878] job release stage : execute_job_release completed...
# [2021-02-02T14:47:26.826379] job release stage : send_run_telemetry starting...
# [2021-02-02T14:47:27.709312] job release stage : send_run_telemetry completed...
# [2021-02-02T14:47:27.709691] Job release is complete
#
# StepRun(Prepare Data) Execution Summary
# ========================================
# StepRun( Prepare Data ) Status: Finished
# {'runId': '7fae51d9-0f1c-4725-bcb6-4faf9f659449', 'target': 'ClusterDP100', 'status': 'Completed', 'startTimeUtc': '2021-02-02T14:43:25.740235Z', 'endTimeUtc': '2021-02-02T14:47:43.913086Z', 'properties': {'ContentSnapshotId': 'a78da589-35f1-42e8-afa2-4bc38fdc9abf', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '1c56b85f-1b18-4337-a722-c68065c473b6', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'e48e1496', 'azureml.pipelinerunid': '8443e42e-9995-4eb6-a12a-ced603fb2407', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '7ebe96a9-0cae-46f8-a4b3-217872040fc0'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'prep_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--input-data', 'DatasetConsumptionConfig:raw_data', '--prepped-data', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'ClusterDP100', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': '7ebe96a9-0cae-46f8-a4b3-217872040fc0', 'name': None, 'version': '2'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_c783a5c2ab4cc46496d2d299e0acf4f2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.7fa ...
# StepRunId: 5ba1074e-11c2-4e5e-bae6-f77a5d963b07
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/5ba1074e-11c2-4e5e-bae6-f77a5d963b07?wsid=/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourcegroups/azuredp-100/workspaces/training_dp100
# StepRun( Train and Register Model ) Status: NotStarted
# StepRun( Train and Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# ========================================================================================================================
# 2021-02-02T14:50:09Z Starting output-watcher...
# 2021-02-02T14:50:09Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-02-02T14:50:10Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-02-02T14:50:10Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
# Digest: sha256:2dec016528f61357caa7418e7b918a596af618fadb981c14411aa4bba56749ed
# Status: Image is up to date for fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90:latest
# 2021-02-02T14:50:12Z Check if container 5ba1074e-11c2-4e5e-bae6-f77a5d963b07 already exist exited with 0,
#
# 0184f4a733863694d3816e43ef52d1328cf05bb081119c61fbc1e6d6e07ef414
# 2021/02/02 14:50:13 Starting App Insight Logger for task:  containerSetup
# 2021/02/02 14:50:13 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# 2021/02/02 14:50:13 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/02 14:50:13 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/02/02 14:50:13 sshd inside container not required for job, skipping setup.
# 2021/02/02 14:50:14 All App Insights Logs was send successfully
# 2021-02-02T14:50:14Z Starting docker container succeeded.
# 2021-02-02T14:50:19Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/02/02 14:50:06 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/02/02 14:50:06 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# >>>   2021/02/02 14:50:06 runtime.GOOS linux
# >>>   2021/02/02 14:50:06 Reading dyanamic configs
# >>>   2021/02/02 14:50:06 Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0N9eHP7a8jepCKE6%2BOvSOLDLAmlD0xCclGbuN66nWKg%3D
# ...
# >>>   2021/02/02 14:50:11 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 5ba1074e-11c2-4e5e-bae6-f77a5d963b07 -m 13675m -w /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/config/.batchai.envlist -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07:/mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07 -v /mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/wd:/mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/wd -v /mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/certs:/mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/certs --shm-size 2g -d -it --privileged --net=host fd5d9572f8b74f5e933fceba46da77ff.azurecr.io/azureml/azureml_54bfcc4ba13e313ba3f67b53ded76c90
# >>>   2021/02/02 14:50:12 Check if container 5ba1074e-11c2-4e5e-bae6-f77a5d963b07 already exist exited with 0,
# >>>
# >>>   2021/02/02 14:50:12 Check if container 5ba1074e-11c2-4e5e-bae6-f77a5d963b07 already exist exited with 0,
# >>>
# >>>   2021/02/02 14:50:14 Container ssh is not required for job type.
# >>>   2021/02/02 14:50:14 Starting docker container succeeded.
# >>>   2021/02/02 14:50:14 Starting docker container succeeded.
# >>>   2021/02/02 14:50:14 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/azureml_compute_logs
# >>>   2021/02/02 14:50:14 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a78da589-35f1-42e8-afa2-4bc38fdc9abf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 14:50:14 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/azureml_compute_logs/65_job_prep-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# >>>   2021/02/02 14:50:14 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/azureml_compute_logs/65_job_prep-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# >>>   2021/02/02 14:50:14 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07;/azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a78da589-35f1-42e8-afa2-4bc38fdc9abf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 14:50:14 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/02/02 14:50:14 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t 5ba1074e-11c2-4e5e-bae6-f77a5d963b07 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/d512a56e-2705-4187-8fe7-7675a3e7e40d/job-1/5ba1074e-11c2-4e5e-b_f72f99eb-7c2d-48a6-9e66-e80529c16c42/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07;/azureml-envs/azureml_c783a5c2ab4cc46496d2d299e0acf4f2/bin/python /mnt/batch/tasks/shared/LS_root/jobs/training_dp100/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/mounts/workspaceblobstore/azureml/5ba1074e-11c2-4e5e-bae6-f77a5d963b07-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a78da589-35f1-42e8-afa2-4bc38fdc9abf","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/02/02 14:50:16 Attempt 1 of http call to https://westeurope.experiments.azureml.net/history/v1.0/private/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourceGroups/azuredp-100/providers/Microsoft.MachineLearningServices/workspaces/training_dp100/runs/5ba1074e-11c2-4e5e-bae6-f77a5d963b07/spans
# >>>   2021/02/02 14:50:19 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:15.015325] Entering job preparation.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:16.614112] Starting job preparation.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:16.614154] Extracting the control code.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:16.644687] fetching and extracting the control code on master node.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:16.644736] Starting extract_project.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:16.644789] Starting to extract zip file.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:17.473508] Finished extracting zip file.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:17.678788] Using urllib.request Python 3.0 or later
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:17.678901] Start fetching snapshots.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:17.678942] Start fetching snapshot.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:17.678955] Retrieving project from snapshot: a78da589-35f1-42e8-afa2-4bc38fdc9abf
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 48
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.188124] Finished fetching snapshot.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.188158] Finished fetching snapshots.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.188174] Finished extract_project.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.200506] Finished fetching and extracting the control code.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.203604] downloadDataStore - Download from datastores if requested.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.205154] Start run_history_prep.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:18.260472] Entering context manager injector.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: Acquired lockfile /tmp/5ba1074e-11c2-4e5e-bae6-f77a5d963b07-datastore.lock to downloading input data references
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:19.069573] downloadDataStore completed
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:19.072525] Job preparation is complete.
# >>>   2021/02/02 14:50:19 runSpecialJobTask: preparation: [2021-02-02T14:50:19.072561] Running Context Managers in Sidecar complete.
# >>>   2021/02/02 14:50:19 All App Insights Logs was send successfully
# >>>   2021/02/02 14:50:19 Process Exiting with Code:  0
# >>>
# 2021-02-02T14:50:19Z 127.0.0.1 slots=2 max-slots=2
# 2021-02-02T14:50:20Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt
# ===============================================================================================================
# [2021-02-02T14:50:35.744809] Entering job release
# [2021-02-02T14:50:36.898451] Starting job release
# [2021-02-02T14:50:36.903273] Logging experiment finalizing status in history service.
# [2021-02-02T14:50:36.903441] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 161
# [2021-02-02T14:50:36.904263] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-02-02T14:50:36.904450] job release stage : execute_job_release starting...
# [2021-02-02T14:50:36.906650] job release stage : copy_batchai_cached_logs starting...
# [2021-02-02T14:50:36.906762] job release stage : copy_batchai_cached_logs completed...
# [2021-02-02T14:50:36.913896] Entering context manager injector.
# [2021-02-02T14:50:37.211612] job release stage : send_run_telemetry starting...
# [2021-02-02T14:50:37.512434] job release stage : execute_job_release completed...
# [2021-02-02T14:50:37.634993] job release stage : upload_datastore completed...
# [2021-02-02T14:50:38.143688] job release stage : send_run_telemetry completed...
# [2021-02-02T14:50:38.144015] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '5ba1074e-11c2-4e5e-bae6-f77a5d963b07', 'target': 'ClusterDP100', 'status': 'Completed', 'startTimeUtc': '2021-02-02T14:50:09.098719Z', 'endTimeUtc': '2021-02-02T14:50:48.628555Z', 'properties': {'ContentSnapshotId': 'a78da589-35f1-42e8-afa2-4bc38fdc9abf', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'e9c7a50e-ecb4-48f3-9072-079664e34316', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '8b0838d8', 'azureml.pipelinerunid': '8443e42e-9995-4eb6-a12a-ced603fb2407', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'ClusterDP100', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/7fae51d9-0f1c-4725-bcb6-4faf9f659449/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.20.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_c783a5c2ab4cc46496d2d299e0acf4f2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.5ba1074e-11c2-4e5e-bae6-f77a5d963b07/azureml-logs/55_azureml-execution-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed7989ad6980_d.txt?sv=2019-02-02&sr=b&sig=Qi6wkrVOKMZct46Kn2OTho2JMUbq283CpxHtGEQ3eos%3D&st=2021-02-02T14%3A40%3A39Z&se=2021-02-02T22%3A50%3A39Z&sp=r', 'azureml-logs/65_job_prep-tvmps_e9952c21a46d47e14b6252516f4833faf440dceb65f5b99372baed798 ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8443e42e-9995-4eb6-a12a-ced603fb2407', 'status': 'Completed', 'startTimeUtc': '2021-02-02T14:29:39.510295Z', 'endTimeUtc': '2021-02-02T14:51:09.793411Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.8443e42e-9995-4eb6-a12a-ced603fb2407/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=CKRXhTIGC1i%2Fns2HN2MnlCJSifVvr7r4JqEK887e0DA%3D&st=2021-02-02T14%3A19%3A58Z&se=2021-02-02T22%3A29%3A58Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.8443e42e-9995-4eb6-a12a-ced603fb2407/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=pmLQ38XSQ%2FFg7TeP4%2FqZGit3dXk7ssOmjbm9rJtlAgE%3D&st=2021-02-02T14%3A19%3A58Z&se=2021-02-02T22%3A29%3A58Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.8443e42e-9995-4eb6-a12a-ced603fb2407/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=N0G5zVK%2FwV0rgFpibBLuo%2FLzLG8LAybfwyX6FPsjz4E%3D&st=2021-02-02T14%3A19%3A58Z&se=2021-02-02T22%3A29%3A58Z&sp=r'}, 'submittedBy': 'Cong Wu'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.9022222222222223
# 	 AUC : 0.8882269613989017
# 	 ROC : aml://artifactId/ExperimentRun/dcid.5ba1074e-11c2-4e5e-bae6-f77a5d963b07/ROC_1612277427.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
# 	 AUC : 0.8882269613989017
# 	 Accuracy : 0.9022222222222223
#
#
# diabetes_model version: 5
# 	 Training context : Compute cluster
# 	 AUC : 0.8814498483013199
# 	 Accuracy : 0.8973333333333333
#
#
# diabetes_model version: 4
# 	 Training context : File dataset
# 	 AUC : 0.8468497021067503
# 	 Accuracy : 0.7788888888888889
#
#
# diabetes_model version: 3
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568595320655352
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# AutoML4ce9669e80 version: 1

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: fc967fb1-4db5-45da-a99a-9b01295a8d4f,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourceGroups/azuredp-100/providers/Microsoft.MachineLearningServices/workspaces/training_dp100/PipelineRuns/PipelineSubmit/fc967fb1-4db5-45da-a99a-9b01295a8d4f)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourceGroups/azuredp-100/providers/Microsoft.MachineLearningServices/workspaces/training_dp100/PipelineRuns/PipelineSubmit/fc967fb1-4db5-45da-a99a-9b01295a8d4f

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'c5a3d6c9-297e-47be-a68e-af67942938e0'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# c5a3d6c9-297e-47be-a68e-af67942938e0
# PipelineRunId: c5a3d6c9-297e-47be-a68e-af67942938e0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/c5a3d6c9-297e-47be-a68e-af67942938e0?wsid=/subscriptions/5ad5904f-f1ef-435d-a6a9-fb12c091604b/resourcegroups/azuredp-100/workspaces/training_dp100
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c5a3d6c9-297e-47be-a68e-af67942938e0', 'status': 'Completed', 'startTimeUtc': '2021-02-02T14:53:38.768557Z', 'endTimeUtc': '2021-02-02T14:53:52.949902Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'fc967fb1-4db5-45da-a99a-9b01295a8d4f'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=b9Iul%2BjBEWzmKLtD9ynV3WHcAiYgPRLoPN2AYX%2BQsg0%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Oe3w%2B3kAh16%2BWZ8w0U89fj1WZ28FMB7XQwykCzNi4Xg%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=bXai6nxF2wZNIJonrX2EkUaxgd2giEhWwvmmrTonZIk%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r'}, 'submittedBy': 'Cong Wu'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: 207f90b6-f764-435e-87da-6436cb8d51c1,
#  Status: Active,
#  Pipeline Id: fc967fb1-4db5-45da-a99a-9b01295a8d4f,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': 'c5a3d6c9-297e-47be-a68e-af67942938e0',
#  'status': 'Completed',
#  'startTimeUtc': '2021-02-02T14:53:38.768557Z',
#  'endTimeUtc': '2021-02-02T14:53:52.949902Z',
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'HTTP',
#   'azureml.parameters': '{}',
#   'azureml.pipelineid': 'fc967fb1-4db5-45da-a99a-9b01295a8d4f'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=b9Iul%2BjBEWzmKLtD9ynV3WHcAiYgPRLoPN2AYX%2BQsg0%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Oe3w%2B3kAh16%2BWZ8w0U89fj1WZ28FMB7XQwykCzNi4Xg%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://trainingdp1002164220074.blob.core.windows.net/azureml/ExperimentRun/dcid.c5a3d6c9-297e-47be-a68e-af67942938e0/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=bXai6nxF2wZNIJonrX2EkUaxgd2giEhWwvmmrTonZIk%3D&st=2021-02-02T14%3A46%3A14Z&se=2021-02-02T22%3A56%3A14Z&sp=r'},
#  'submittedBy': 'Cong Wu'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
